# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# ...
#   Created wheel for citipy: filename=citipy-0.0.5-py3-none-any.whl size=559704 sha256=ce8945f656b817bda57c300db53437d9f85ed0eec3e3eb20f5fb194116cadbf6
#   Stored in directory: c:\users\zhoga\appdata\local\pip\cache\wheels\6d\df\5e\ad8eb9cc5ee7f4ba76865167c09f9a7edff405c669111d8353
# Successfully built citipy
# ...

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %%
cities[:20]
# Out:
# ['nizhneyansk',
#  'fortuna',
#  'makakilo city',
#  'le port',
#  'muros',
#  'yulara',
#  'new norfolk',
#  'rikitea',
#  'jumla',
#  'avarua',
#  'lorengau',
#  'hilo',
#  'carnarvon',
#  'matagami',
#  'barrow',
#  'santa rosa',
#  'mataura',
#  'bambous virieux',
#  'saint george',
#  'kamaishi']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
sample_city='kamaishi'


# Build partial query URL

query_url = f"{url}appid={weather_api_key}&units={units}&q="

output=requests.get(query_url+sample_city).json()
output
# Out:
# {'coord': {'lon': 141.8833, 'lat': 39.2667},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 4.31,
#   'feels_like': 1.22,
#   'temp_min': 4.31,
#   'temp_max': 4.31,
#   'pressure': 1009,
#   'humidity': 84,
#   'sea_level': 1009,
#   'grnd_level': 1008},
#  'visibility': 9474,
#  'wind': {'speed': 1.99, 'deg': 252},
#  'clouds': {'all': 83},
#  'dt': 1612639211,
#  'sys': {'country': 'JP', 'sunrise': 1612647239, 'sunset': 1612684755},
#  'timezone': 32400,
#  'id': 2112444,
#  'name': 'Kamaishi',
#  'cod': 200}

# %%
lat=[]
lon=[]
temp=[]
humidity=[]
clouds=[]
wind=[]
country=[]
date=[]
cityname=[]

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response['coord']['lat'])    
        lon.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        cityname.append(city)

        print(city)
    except:
        print("city not found")
    time.sleep(1)
# Out:
# nelson bay
# rikitea
# brae
# vokhtoga
# hobart
# avarua
# qaanaaq
# tessalit
# mataura
# city not found
# bluff
# ushuaia
# carnarvon
# tiksi
# yellowknife
# punta arenas
# san luis
# atuona
# vaini
# port alfred
# zatoka
# city not found
# dikson
# chokurdakh
# marsabit
# torbay
# bambous virieux
# tabou
# vao
# ancud
# buala
# albany
# jamestown
# busselton
# city not found
# castro
# kodiak
# camacha
# provideniya
# thompson
# new norfolk
# henties bay
# pevek
# city not found
# faanui
# city not found
# antofagasta
# klaksvik
# dingle
# mar del plata
# esperance
# fort nelson
# kapaa
# city not found
# hithadhoo
# clyde river
# bengkulu
# lere
# zhezkazgan
# lorengau
# cape town
# city not found
# saskylakh
# kota tinggi
# ilulissat
# victoria
# svetlogorsk
# nizwa
# slave lake
# delano
# nybro
# longyearbyen
# hilo
# bukama
# barrow
# auki
# parakou
# huntington
# guiratinga
# kruisfontein
# padang
# city not found
# hambantota
# tocache
# hermanus
# city not found
# ...

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
lat=[]
lon=[]
temp=[]
humidity=[]
clouds=[]
wind=[]
country=[]
date=[]
cityname=[]

# %%
#create data frame

weather_dict = {
    "City": cityname,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": temp,
    "Humidity":humidity,
    "Cloudiness":clouds,
    "Wind Speed":wind,
    "Country":country,
    "Date":date
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  nelson bay -32.7167  152.1500     21.00       100          40        4.12
# 1     rikitea -23.1203 -134.9692     25.40        73         100        5.20
# 2        brae  60.3964   -1.3530      1.00        51         100        9.26
# 3    vokhtoga  58.8147   41.0461    -19.25        91         100        4.41
# 4      hobart -42.8794  147.3294     14.44        77          93        1.54
#
#   Country        Date
# 0      AU  1612639193
# 1      PF  1612639212
# 2      GB  1612639213
# 3      RU  1612639215
# 4      AU  1612638922

# %%
#Convert raw data to CSV

weather_data.to_csv("output_data/cities.csv", index = False)

# %%
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  599.000000  599.000000  599.000000  599.000000  599.000000  599.000000
# mean    19.877028   19.568998   69.794808   69.353923   51.569282    7.979416
# std     33.262944   91.418472   15.678452   22.704698   35.405602    5.660694
# min    -54.800000 -179.170000   12.200000    7.000000    0.000000    0.360000
# 25%     -8.540000  -61.210000   59.000000   55.000000   20.000000    3.620000
# 50%     24.370000   24.670000   73.110000   75.000000   59.000000    6.730000
# 75%     46.585000  102.255000   80.600000   87.000000   85.000000   11.050000
# max     78.220000  179.320000  116.600000  100.000000  100.000000   42.500000
#
#                Date
# count  5.990000e+02
# mean   1.593605e+09
# std    5.738815e+01
# min    1.593605e+09
# 25%    1.593605e+09
# 50%    1.593605e+09
# 75%    1.593605e+09
# max    1.593605e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

humidity_check=weather_data.loc[weather_data["Humidity"]>=100]
humidity_check
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        nelson bay -32.7167  152.1500     21.00       100          40
# 11        carnarvon -24.8667  113.6333     27.00       100          40
# 74       hambantota   6.1241   81.1185     23.00       100          20
# 94         buraydah  26.3260   43.9750     10.00       100          75
# 136           airai  -8.9266  125.4092     15.73       100         100
# 161         bintulu   3.1667  113.0333     25.00       100          40
# 170            sola -13.8833  167.5500     24.00       100          20
# 185       martapura  -3.4167  114.8500     25.00       100         100
# 222      strezhevoy  60.7333   77.5889      0.00       100          90
# 236            gasa  31.5000   34.4667     15.56       100           0
# 276   clarence town -32.5833  151.7833     21.00       100          40
# 285             gat  31.6100   34.7642     15.56       100           1
# ...

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
humidity_check.count()
# Out:
# City          24
# Lat           24
# Lng           24
# Max Temp      24
# Humidity      24
# Cloudiness    24
# Wind Speed    24
# Country       24
# Date          24
# dtype: int64

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#create data frame

#humidity_df = {"Humidity":humidity}               ]

cities = pd.read_csv("output_data/cities.csv", encoding="utf-8")


#cities.sort_values("Humidity", inplace=True)
cities.drop_duplicates(subset="Humidity",keep=False, inplace=True)

cities.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 7    tessalit  20.1986   1.0114     25.61        16          94        3.95
# 51       lere  10.3870   8.5726     23.11        21         100        3.42
# 85      kutum  14.2000  24.6667     13.57        34           0        4.91
# 142     sabha  27.0377  14.4283     19.20        24         100        4.04
# 191  westport  41.1415 -73.3579      7.00        39          20        5.66
#
#     Country        Date
# 7        ML  1612639415
# 51       NG  1612639470
# 85       SD  1612639513
# 142      LY  1612639579
# 191      US  1612639624

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature (2/7/21)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperaturevsLat.png")

# Show plot
plt.show()

# %%
#The max temperature is showing at 0 latitude. As the latidude increases or decreases temperature drops.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (2/7/21)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LATvsHUM.png")

# Show plot
plt.show()

# %%
#Polar regions have lower humidity and as latitude gets higher,humidity gets higher in southern hemisphere.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (2/7/21)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LATvsCloud.png")

# Show plot
plt.show()

# %%
#Cloudiness is scattered accross the lattitude.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (2/7/21)")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("LATvsWind.png")

# Show plot
plt.show()

# %%
#Wind speed is mostly scrattered spread accross the lower Latituderegion

# %% [markdown]
# ## Linear Regression

# %%
# Create DataFrames for Northern and Southern Hemisphere 

northern_hemisphere = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemisphere = weather_data.loc[weather_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Define plotting function

def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    plt.savefig("LinearMaxtempNorth.png")
    plt.show()

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (0,25)
plotLinearRegression(northern_hemisphere[xlbl],northern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.8501491639464291

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Max Temp"
lblpos = (-55,90)
plotLinearRegression(southern_hemisphere[xlbl],southern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.5842285834394669

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (45,10)
plotLinearRegression(northern_hemisphere[xlbl],northern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.3051967515309453

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Humidity"
lblpos = (-55,90)
plotLinearRegression(southern_hemisphere[xlbl],southern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.18592519456002377

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (45,10)
plotLinearRegression(northern_hemisphere[xlbl],northern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.2834429686274395

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-55,90)
plotLinearRegression(southern_hemisphere[xlbl],southern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.2683083440651215

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (45,10)
plotLinearRegression(northern_hemisphere[xlbl],northern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.19209898820898633

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-55,90)
plotLinearRegression(southern_hemisphere[xlbl],southern_hemisphere[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: -0.1635296203810744

# %%
# Out:
# The r-value is: 0.017128274759839232
